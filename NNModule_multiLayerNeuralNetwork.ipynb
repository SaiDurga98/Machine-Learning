# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiDurga98/Machine-Learning/blob/main/NNModule_multiLayerNeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

class Model(nn.Module):

  # Sequential Containers can be used during forward pass
  def __init__(self, num_features):
    super().__init__()
    self.network = nn.Sequential(
        nn.Linear(num_features, 3),
        nn.ReLU(),
        nn.Linear(3, 1),
        nn.Sigmoid()
    )

  def forward(self, features):
    return self.network(features)

  # def __init__(self, num_features):
  #   super().__init__()
  #   self.linear1 = nn.Linear(num_features, 3) # 3 hidden layers
  #   self.relu = nn.ReLU()
  #   self.linear2 = nn.Linear(3, 1) # and then last 1 layer
  #   self.sigmoid = nn.Sigmoid()

  # def forward(self, features):
  #   out = self.linear1(features)
  #   out = self.relu(out)
  #   out = self.linear2(out)
  #   out = self.sigmoid(out)
  #   return out

# %%
# create dataset
features = torch.rand(10,5)

# create model
model = Model(features.shape[1])

# call model for forward pass
# model.forward(features)
model(features)
# Out:
# tensor([[0.6472],
#         [0.6463],
#         [0.6544],
#         [0.6554],
#         [0.6469],
#         [0.6198],
#         [0.6607],
#         [0.6672],
#         [0.6719],
#         [0.6579]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# **5 inputs → 3 hidden neurons → 1 output**
#
# 5 inputs, 3 outputs → weights (3,5) + bias (3,) -> 15 weights and 3 bias
#
# layer2 = nn.Linear(3, 1)   # 3 inputs, 1 output → weights (1,3) + bias (1,) -> 3 weights and 1 bias

# %%
model.network
# Out:
# Sequential(
#   (0): Linear(in_features=5, out_features=3, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=3, out_features=1, bias=True)
#   (3): Sigmoid()
# )

# %% [markdown]
# total 3 weights in the next layer

# %%
model.linear2.weight
# Out:
# Parameter containing:
# tensor([[-0.2595,  0.0242,  0.3265]], requires_grad=True)

# %%
# !pip install torchinfo

# %%
from torchinfo import summary

summary(model, input_size=(10, 5))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# Model                                    [10, 1]                   --
# ├─Sequential: 1-1                        [10, 1]                   --
# │    └─Linear: 2-1                       [10, 3]                   18
# │    └─ReLU: 2-2                         [10, 3]                   --
# │    └─Linear: 2-3                       [10, 1]                   4
# │    └─Sigmoid: 2-4                      [10, 1]                   --
# ...
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ...
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ...
